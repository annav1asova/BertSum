# %%
import pandas as pd
import  tarfile
import os
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/avlasova/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
fragments_path = "/data/fragments.tar"
abstracts_path = "/data/abstracts.tar"

# %%
tar = tarfile.open(os.getenv("HOME") + fragments_path)
tar_members = tar.getmembers()
index = 0
fragments_file = tar.extractfile(tar_members[index])
fragments_df = pd.read_csv(fragments_file, sep='\t', header=None, 
                           names=['id', 'fragment_text'])

# %%
fragments_df
# Out:
#                                     id  \
# 0        PMC0014XXXXX/PMC1416283.xml/1
# 1        PMC0014XXXXX/PMC1416283.xml/2
# 2        PMC0014XXXXX/PMC1416283.xml/3
# 3        PMC0014XXXXX/PMC1416283.xml/4
# 4        PMC0014XXXXX/PMC1416283.xml/5
# ...                                ...
# 350969  PMC0063XXXXX/PMC6342651.xml/25
# 350970  PMC0063XXXXX/PMC6342651.xml/26
# 350971  PMC0063XXXXX/PMC6342651.xml/27
# 350972  PMC0063XXXXX/PMC6342651.xml/28
# 350973  PMC0063XXXXX/PMC6342651.xml/29
#
#                                             fragment_text
# 0       Blocking AMPA/kainate receptors attenuates whi...
# 1       Whole-cell clamped precursor, immature and mat...
# 2       Precursor, immature and mature cerebellar whit...
# 3       NMDA (60μM) evoked an inward current in corpus...
# 4       Ifenprodil (10μM), which blocks NR2B-containin...
# ...                                                   ...
# 350969  As shown before, treatment of muscle cells wit...
# 350970  The main physiological function of GLP-1 is to...
# 350971  Expression of GLP-1R is present in peripheral ...
# 350972  The present study examined the expression of G...
# 350973  Previous studies have shown that GLP-1R agonis...
#
# [350974 rows x 2 columns]

# %%
tar = tarfile.open(os.getenv("HOME") + abstracts_path)
tar_members = tar.getmembers()
abstracts_file = tar.extractfile(tar_members[index])
abstracts_df = pd.read_csv(abstracts_file, sep='\t', header=None, 
                           names=['id', 'abtract_text'])

# %%
abstracts_df
# Out:
#                                  id  \
# 0     PMC0014XXXXX/PMC1416283.xml/1
# 1     PMC0014XXXXX/PMC1459476.xml/1
# 2     PMC0014XXXXX/PMC1457108.xml/1
# 3     PMC0018XXXXX/PMC1872050.xml/1
# 4     PMC0018XXXXX/PMC1828212.xml/1
# ...                             ...
# 9217  PMC0063XXXXX/PMC6390403.xml/1
# 9218  PMC0063XXXXX/PMC6317363.xml/1
# 9219  PMC0063XXXXX/PMC6354590.xml/1
# 9220  PMC0063XXXXX/PMC6354590.xml/2
# 9221  PMC0063XXXXX/PMC6342651.xml/1
#
#                                            abtract_text
# 0     Glutamate-mediated damage to oligodendrocytes ...
# 1     We describe two homologues of the mammalian di...
# 2     This study describes staffing, caseloads and r...
# 3     Evolutionary ecology predicts that parasite li...
# 4     It has been proposed that substance P and calc...
# ...                                                 ...
# 9217  This paper proposes the creation and applicati...
# 9218  The study’s objectives were to investigate the...
# 9219  Tumor growth and relapse are driven by tumor p...
# 9220  Hayes et al. find that Vangl2 specifically lab...
# 9221  The insulinotropic effects of the incretin hor...
#
# [9222 rows x 2 columns]

# %%
def divide_article_id(article):
    id_splitted = article.split('/')
    article_id, second_id = id_splitted[1].split('.')[0], id_splitted[2]
    return pd.Series([article_id, second_id])

# %%
abstracts_df[['article_id', 'abstract_id']] = abstracts_df['id'].apply(lambda row: divide_article_id(row))

# %%
fragments_df[['article_id', 'fragment_id']] = fragments_df['id'].apply(lambda row: divide_article_id(row))

# %%
fragments_df.drop(columns=['id'], inplace=True)
abstracts_df.drop(columns=['id'], inplace=True)

# %%
fragments_df
# Out:
#                                             fragment_text  article_id  \
# 0       Phosphoinositides (PIs),[xref] phosphorylated ...  PMC1838524
# 1       The PX domain was first identified within a se...  PMC1838524
# 2       The atomic resolution crystal and solution str...  PMC1838524
# 3       The Vam7p t-SNARE (soluble N-ethylmaleimide-se...  PMC1838524
# 4       DNA fragments encoding residues 2-122 of the y...  PMC1838524
# ...                                                   ...         ...
# 361680  RNA was isolated from cells and tissues as des...  PMC6377304
# 361681  Western blotting was performed as described[xr...  PMC6377304
# 361682  The concentration of nitrite (NO2−), the oxidi...  PMC6377304
# 361683  IL-1β was assessed using an R&D DuoSet ELISA k...  PMC6377304
# 361684  Data are displayed as mean ± S.E.M. Outlier te...  PMC6377304
#
#        fragment_id
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
# ...            ...
# 361680          32
# 361681          33
# 361682          34
# 361683          35
# 361684          36
#
# [361685 rows x 3 columns]

# %%
texts_df = fragments_df.groupby('article_id')['fragment_text']\
            .apply(lambda x: '\n'.join(x)).reset_index()\
            .rename(columns={'fragment_text':'article_text'})

# %%
papers_df = pd.merge(texts_df, abstracts_df, on='article_id')

# %%
papers_df
# Out:
#        article_id                                       article_text  \
# 0      PMC1283128  There are two principal active end products of...
# 1      PMC1397880  On 4 February 1935, an agitated Honor Fell, th...
# 2      PMC1564435  Fatal self-harm is a global problem responsibl...
# 3      PMC1602059  At least four transposable elements have been ...
# 4      PMC1634803  Transient receptor potential (TRP) channels ar...
# ...           ...                                                ...
# 11242  PMC6441973  Prostate cancer is among the most common cance...
# 11243  PMC6443446  Mate, a traditional nonalcoholic drink, is an ...
# 11244  PMC6444363  Tat protein is neurotoxic in vitro. A variety ...
# 11245  PMC6446232  We are pleased to join the colleagues, student...
# 11246  PMC6450074  With the advance of array and sequencing-based...
#
#                                             abtract_text abstract_id
# 0      18-hydroxycortisol (18-OHF) and 18-oxocortisol...           1
# 1      The technique of tissue culture has, throughou...           1
# 2      Although the high rate of elderly suicide is c...           1
# 3      Current techniques for the genetic engineering...           1
# 4      TRPM2 proteins belong to the melastatin-relate...           1
# ...                                                  ...         ...
# 11242  The therapeutic landscape of prostate cancer h...           1
# 11243  Drinking mate, an infusion of the herb ilex pa...           1
# 11244  HIV-1 Tat is known to be neurotoxic and import...           1
# 11245  Methionine in proteins is often thought to be ...           1
# 11246  Modern bio-technologies have produced a vast a...           1
#
# [11247 rows x 4 columns]

# %%
def write_to_file(article):
    article_id, full_text, abstract, abstract_id = article
    article_sentences = nltk.tokenize.sent_tokenize(full_text)
    abstract_sentences = nltk.tokenize.sent_tokenize(abstract)
    
    full_text = '\n\n'.join(article_sentences)
    
    sep = '@highlight\n\n'
    summary = sep + ('\n\n' + sep).join(abstract_sentences)
    
    res_article = '\n\n'.join([full_text, summary])
        
    f = open( os.getenv("HOME") + '/BertSum/raw_data/{}.paper'.format(article_id),'w+')
    f.write(res_article)
    f.close()

# %%
papers_df.apply(lambda article: write_to_file(article), axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 11242    None
# 11243    None
# 11244    None
# 11245    None
# 11246    None
# Length: 11247, dtype: object
